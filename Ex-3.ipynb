# %%
# Exp.no:3
# Aim:To perform basics of data frame.
# Name:Vedanti B. Tayade
# Roll no:65
# Sec:B
# Sub:ET1
# Date:07/08/2025

# %% [markdown]
# # Creating Series

# %%
import pandas as pd

# %%
Name=["Vedanti","Shrutika","Sakshi","Pranali","Himani","Sanika","Shrushti","Indrani"]
Name
# Out:
# ['Vedanti',
#  'Shrutika',
#  'Sakshi',
#  'Pranali',
#  'Himani',
#  'Sanika',
#  'Shrushti',
#  'Indrani']

# %%
print(Name)
# Out:
# ['Vedanti', 'Shrutika', 'Sakshi', 'Pranali', 'Himani', 'Sanika', 'Shrushti', 'Indrani']

# %%
Roll_list=pd.Series(Name,index=[1,2,3,4,5,6,7,8])
print(Roll_list)
# Out:
# 1     Vedanti
# 2    Shrutika
# 3      Sakshi
# 4     Pranali
# 5      Himani
# 6      Sanika
# 7    Shrushti
# 8     Indrani
# dtype: object

# %% [markdown]
#  # Creating Data Frame

# %%
import pandas as pd

# %%
df=pd.DataFrame([[1,2,3,4],[7,8,9,5],[6,8,4,6],[8,5,6,9]],
columns=["CD","DSS","CAO","DBMS"])

# %%
df
# Out:
#    CD  DSS  CAO  DBMS
# 0   1    2    3     4
# 1   7    8    9     5
# 2   6    8    4     6
# 3   8    5    6     9

# %%
df.shape
# Out:
# (4, 4)

# %%
df.size
# Out:
# 16

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Adding Record (Row) to the data frame

# %%
df2=pd.DataFrame([[10,20,30,40]],
columns=["CD","DSS","CAO","DBMS"])

# %%
df3=df.append(df2,ignore_index=True)

# %%
df3
# Out:
#    CD  DSS  CAO  DBMS
# 0   1    2    3     4
# 1   7    8    9     5
# 2   6    8    4     6
# 3   8    5    6     9
# 4  10   20   30    40

# %%
df3.shape
# Out:
# (5, 4)

# %%
df3.size
# Out:
# 20

# %%
df3.ndim
# Out:
# 2

# %% [markdown]
# # Adding attribute (columns) name DM

# %%
df3["DM"]=[3,6,5,8,7]

# %%
df3
# Out:
#    CD  DSS  CAO  DBMS  DM
# 0   1    2    3     4   3
# 1   7    8    9     5   6
# 2   6    8    4     6   5
# 3   8    5    6     9   8
# 4  10   20   30    40   7

# %% [markdown]
# # Deleting Record from df3 data frame

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DSS  CAO  DBMS  DM
# 0   1    2    3     4   3
# 2   6    8    4     6   5
# 3   8    5    6     9   8
# 4  10   20   30    40   7

# %% [markdown]
# # Deleting Attribute (columns)from df3 dataframe

# %%
df5=df3.drop(columns=['DM'])

# %% [markdown]
# df5

# %% [markdown]
# # Finding Mean Median Mode

# %%
print("mean of DSS:",df5["DSS"].mean())
# Out:
# mean of DSS: 8.6

# %%
print("median of DSS:",df5["DSS"].median())
# Out:
# median of DSS: 8.0

# %%
print("mode of DSS:",df5["DSS"].mode())
# Out:
# mode of DSS: 0    8
# dtype: int64
