# %%
# Exp.no:2
# Aim:To perform operationof central tendency of measures.
# Name:Vedanti B. Tayade
# Roll no:65
# Sec:B
# Sub:ET1
# Date:31/07/2025

# %% [markdown]
# # To perform operation of central tendency of measures(Mean,Mode,Median)

# %%
age = [20,21,22,23,22,22,21,22,21,21,22.24]

# %%
print(age)
# Out:
# [20, 21, 22, 23, 22, 22, 21, 22, 21, 21, 22.24]

# %%
age
# Out:
# [20, 21, 22, 23, 22, 22, 21, 22, 21, 21, 22.24]

# %%
import statistics as st

# %%
a=st.mean(age)

# %%
a
# Out:
# 21.567272727272726

# %%
b=st.median(age)

# %%
b
# Out:
# 22

# %%
c=st.mode(age)

# %%
c
# Out:
# 21

# %% [markdown]
# # Performing central tendency of measures using numpy

# %%
import numpy as np

# %%
x=np.array([1,2,3,4,5,6,2,3,5,6])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 2, 3, 5, 6])

# %%
print(np.mean(x))
# Out:
# 3.7

# %%
print(np.median(x))
# Out:
# 3.5

# %% [markdown]
# # Preforming central tendency of measures using scipy

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=array([2]), count=array([2]))

# %%
print(np.std(x))
# Out:
# 1.676305461424021

# %%
print(np.var(x))
# Out:
# 2.81
